# %% [markdown]
# ### Importing pandas pymongo and json

# %%
import pandas as pd
import pymongo 
import json

# %% [markdown]
# ### Reading CSV file

# %%
file = pd.read_csv(r"C:\Users\admin\Downloads\archive\ufo-sightings-transformed.csv")

# %% [markdown]
# ### Displaying the file

# %%
file
# Out:
#        Unnamed: 0            Date_time date_documented  Year  Month  Hour  \
# 0               0  1949-10-10 20:30:00       4/27/2004  1949     10    20
# 1               1  1949-10-10 21:00:00      12/16/2005  1949     10    21
# 2               2  1955-10-10 17:00:00       1/21/2008  1955     10    17
# 3               3  1956-10-10 21:00:00       1/17/2004  1956     10    21
# 4               4  1960-10-10 20:00:00       1/22/2004  1960     10    20
# ...           ...                  ...             ...   ...    ...   ...
# 80323       80323  2013-09-09 21:15:00       9/30/2013  2013      9    21
# 80324       80324  2013-09-09 22:00:00       9/30/2013  2013      9    22
# 80325       80325  2013-09-09 22:00:00       9/30/2013  2013      9    22
# 80326       80326  2013-09-09 22:20:00       9/30/2013  2013      9    22
# 80327       80327  2013-09-09 23:00:00       9/30/2013  2013      9    23
#
#        Season Country_Code         Country      Region        Locale  \
# ...

# %% [markdown]
#  ### Checking Datatypes of column

# %%
file.dtypes
# Out:
# Unnamed: 0                       int64
# Date_time                       object
# date_documented                 object
# Year                             int64
# Month                            int64
# Hour                             int64
# Season                          object
# Country_Code                    object
# Country                         object
# Region                          object
# Locale                          object
# latitude                       float64
# longitude                      float64
# UFO_shape                       object
# length_of_encounter_seconds    float64
# Encounter_Duration              object
# Description                     object
# dtype: object

# %% [markdown]
# ### Showing top 5 rows

# %%
file.head()
# Out:
#    Unnamed: 0            Date_time date_documented  Year  Month  Hour  Season  \
# 0           0  1949-10-10 20:30:00       4/27/2004  1949     10    20  Autumn
# 1           1  1949-10-10 21:00:00      12/16/2005  1949     10    21  Autumn
# 2           2  1955-10-10 17:00:00       1/21/2008  1955     10    17  Autumn
# 3           3  1956-10-10 21:00:00       1/17/2004  1956     10    21  Autumn
# 4           4  1960-10-10 20:00:00       1/22/2004  1960     10    20  Autumn
#
#   Country_Code         Country   Region        Locale   latitude   longitude  \
# 0          USA   United States    Texas    San Marcos  29.883056  -97.941111
# 1          USA   United States    Texas  Bexar County  29.384210  -98.581082
# 2          GBR  United Kingdom  England       Chester  53.200000   -2.916667
# 3          USA   United States    Texas          Edna  28.978333  -96.645833
# 4          USA   United States   Hawaii       Kaneohe  21.418056 -157.803611
#
# ...

# %% [markdown]
# ### Showing last 5 rows

# %%
file.tail()
# Out:
#        Unnamed: 0            Date_time date_documented  Year  Month  Hour  \
# 80323       80323  2013-09-09 21:15:00       9/30/2013  2013      9    21
# 80324       80324  2013-09-09 22:00:00       9/30/2013  2013      9    22
# 80325       80325  2013-09-09 22:00:00       9/30/2013  2013      9    22
# 80326       80326  2013-09-09 22:20:00       9/30/2013  2013      9    22
# 80327       80327  2013-09-09 23:00:00       9/30/2013  2013      9    23
#
#        Season Country_Code        Country      Region      Locale   latitude  \
# 80323  Autumn          USA  United States   Tennessee   Nashville  36.165833
# 80324  Autumn          USA  United States       Idaho       Boise  43.613611
# 80325  Autumn          USA  United States  California  Napa Abajo  38.297222
# 80326  Autumn          USA  United States    Virginia      Vienna  38.901111
# 80327  Autumn          USA  United States    Oklahoma      Edmond  35.652778
#
# ...

# %% [markdown]
# ### Checking the no of rows and columns of the CSV file

# %%
file.shape
# Out:
# (80328, 17)

# %% [markdown]
# ### Checking the count of null values

# %%
file.isnull().sum()
# Out:
# Unnamed: 0                        0
# Date_time                         0
# date_documented                   0
# Year                              0
# Month                             0
# Hour                              0
# Season                            0
# Country_Code                    259
# Country                         259
# Region                          566
# Locale                          457
# latitude                          0
# longitude                         0
# UFO_shape                      1930
# length_of_encounter_seconds       0
# Encounter_Duration                0
# Description                      15
# dtype: int64

# %% [markdown]
# ### Imputing null values for the UFO_Shape column

# %%
file.UFO_shape.value_counts()
# Out:
# UFO_shape
# Light        18495
# Triangle      7865
# Circle        7607
# Fireball      6208
# Other         5649
# Unknown       5584
# Sphere        5387
# Disk          5213
# Oval          3733
# Formation     2457
# Cigar         2057
# Changing      1962
# Flash         1328
# Rectangle     1296
# Cylinder      1283
# Diamond       1178
# Chevron        952
# Egg            759
# Teardrop       750
# Cone           316
# Cross          233
# Delta            7
# Round            2
# Crescent         2
# Pyramid          1
# Flare            1
# Hexagon          1
# Dome             1
# Changed          1
# Name: count, dtype: int64

# %% [markdown]
# ### Imputing with mode

# %%
mode_value = file.UFO_shape.mode()[0]
file.UFO_shape.fillna(mode_value)
# Out:
# 0        Cylinder
# 1           Light
# 2          Circle
# 3          Circle
# 4           Light
#            ...
# 80323       Light
# 80324      Circle
# 80325       Other
# 80326      Circle
# 80327       Cigar
# Name: UFO_shape, Length: 80328, dtype: object

# %% [markdown]
# ### Checking the count of null values in UFO_shape column

# %%
print("Null values in 'UFO_shape' column after imputation:", file.UFO_shape.isnull().sum())
# Out:
# Null values in 'UFO_shape' column after imputation: 0

# %%
file.isnull().sum()
# Out:
# Unnamed: 0                       0
# Date_time                        0
# date_documented                  0
# Year                             0
# Month                            0
# Hour                             0
# Season                           0
# Country_Code                   259
# Country                        259
# Region                         566
# Locale                         457
# latitude                         0
# longitude                        0
# UFO_shape                        0
# length_of_encounter_seconds      0
# Encounter_Duration               0
# Description                     15
# dtype: int64

# %% [markdown]
# ### Dropping a column

# %%
file = file.drop("Description" , axis=1)

# %%
file.isnull().sum()
# Out:
# Unnamed: 0                       0
# Date_time                        0
# date_documented                  0
# Year                             0
# Month                            0
# Hour                             0
# Season                           0
# Country_Code                   259
# Country                        259
# Region                         566
# Locale                         457
# latitude                         0
# longitude                        0
# UFO_shape                        0
# length_of_encounter_seconds      0
# Encounter_Duration               0
# dtype: int64

# %% [markdown]
# ### Creating connection to mongodb

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %% [markdown]
# ### Converting the data to a dictionary format to store in mongoDB

# %%
data = file.to_dict(orient ="records")

# %%
data
# Out:
# [{'Unnamed: 0': 0,
#   'Date_time': '1949-10-10 20:30:00',
#   'date_documented': '4/27/2004',
#   'Year': 1949,
#   'Month': 10,
#   'Hour': 20,
#   'Season': 'Autumn',
#   'Country_Code': 'USA',
#   'Country': 'United States',
#   'Region': 'Texas',
#   'Locale': 'San Marcos',
#   'latitude': 29.8830556,
#   'longitude': -97.9411111,
#   'UFO_shape': 'Cylinder',
#   'length_of_encounter_seconds': 2700.0,
#   'Encounter_Duration': '45 minutes'},
#  {'Unnamed: 0': 1,
#   'Date_time': '1949-10-10 21:00:00',
#   'date_documented': '12/16/2005',
#   'Year': 1949,
#   'Month': 10,
#   'Hour': 21,
#   'Season': 'Autumn',
#   'Country_Code': 'USA',
#   'Country': 'United States',
#   'Region': 'Texas',
#   'Locale': 'Bexar County',
#   'latitude': 29.38421,
#   'longitude': -98.581082,
#   'UFO_shape': 'Light',
#   'length_of_encounter_seconds': 7200.0,
#   'Encounter_Duration': '1-2 hrs'},
#  {'Unnamed: 0': 2,
#   'Date_time': '1955-10-10 17:00:00',
#   'date_documented': '1/21/2008',
# ...

# %% [markdown]
# ### Creating a database

# %%
db = client["UFO_Sightings"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'UFO_Sightings')

# %% [markdown]
# ### Creating collection and inserting the values

# %%
db.Newcollection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('66ac7ec80c332c7280dfd617'), ObjectId('66ac7ec80c332c7280dfd618'), ObjectId('66ac7ec80c332c7280dfd619'), ObjectId('66ac7ec80c332c7280dfd61a'), ObjectId('66ac7ec80c332c7280dfd61b'), ObjectId('66ac7ec80c332c7280dfd61c'), ObjectId('66ac7ec80c332c7280dfd61d'), ObjectId('66ac7ec80c332c7280dfd61e'), ObjectId('66ac7ec80c332c7280dfd61f'), ObjectId('66ac7ec80c332c7280dfd620'), ObjectId('66ac7ec80c332c7280dfd621'), ObjectId('66ac7ec80c332c7280dfd622'), ObjectId('66ac7ec80c332c7280dfd623'), ObjectId('66ac7ec80c332c7280dfd624'), ObjectId('66ac7ec80c332c7280dfd625'), ObjectId('66ac7ec80c332c7280dfd626'), ObjectId('66ac7ec80c332c7280dfd627'), ObjectId('66ac7ec80c332c7280dfd628'), ObjectId('66ac7ec80c332c7280dfd629'), ObjectId('66ac7ec80c332c7280dfd62a'), ObjectId('66ac7ec80c332c7280dfd62b'), ObjectId('66ac7ec80c332c7280dfd62c'), ObjectId('66ac7ec80c332c7280dfd62d'), ObjectId('66ac7ec80c332c7280dfd62e'), ObjectId('66ac7ec80c332c7280dfd62f'), ObjectId('66ac7ec80c332c7280df
# ...
